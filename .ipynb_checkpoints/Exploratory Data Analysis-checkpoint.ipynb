# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display
pd.options.display.max_columns = None

# %%
# Read in data
df = pd.read_csv('Train.csv')
df.head()
# Out:
#         Place_ID X Date        Date Place_ID  target  target_min  target_max  \
# 0  010Q650 X 2020-01-02  2020-01-02  010Q650    38.0        23.0        53.0
# 1  010Q650 X 2020-01-03  2020-01-03  010Q650    39.0        25.0        63.0
# 2  010Q650 X 2020-01-04  2020-01-04  010Q650    24.0         8.0        56.0
# 3  010Q650 X 2020-01-05  2020-01-05  010Q650    49.0        10.0        55.0
# 4  010Q650 X 2020-01-06  2020-01-06  010Q650    21.0         9.0        52.0
#
#    target_variance  target_count  precipitable_water_entire_atmosphere  \
# 0           769.50            92                             11.000000
# 1          1319.85            91                             14.600000
# 2          1181.96            96                             16.400000
# 3          1113.67            96                              6.911948
# 4          1164.82            95                             13.900001
#
#    relative_humidity_2m_above_ground  specific_humidity_2m_above_ground  \
# 0                          60.200001                            0.00804
# 1                          48.799999                            0.00839
# 2                          33.400002                            0.00750
# 3                          21.300001                            0.00391
# 4                          44.700001                            0.00535
#
#    temperature_2m_above_ground  u_component_of_wind_10m_above_ground  \
# 0                    18.516840                              1.996377
# 1                    22.546533                              3.330430
# 2                    27.031030                              5.065727
# 3                    23.971857                              3.004001
# 4                    16.816309                              2.621787
#
#    v_component_of_wind_10m_above_ground  L3_NO2_NO2_column_number_density  \
# 0                             -1.227395                          0.000074
# 1                             -1.188108                          0.000076
# 2                              3.500559                          0.000067
# 3                              1.099468                          0.000083
# 4                              2.670559                          0.000070
#
#    L3_NO2_NO2_slant_column_number_density  L3_NO2_absorbing_aerosol_index  \
# 0                                0.000156                       -1.231330
# 1                                0.000197                       -1.082553
# 2                                0.000170                       -1.001242
# 3                                0.000175                       -0.777019
# 4                                0.000142                        0.366323
#
#    L3_NO2_cloud_fraction  L3_NO2_sensor_altitude  L3_NO2_sensor_azimuth_angle  \
# 0               0.006507           840209.874619                    76.537512
# 1               0.018360           840772.941995                   -14.708036
# 2               0.015904           841410.713456                  -105.201338
# 3               0.055765           841103.242368                  -104.334056
# 4               0.028530           840763.055499                    58.850179
#
#    L3_NO2_sensor_zenith_angle  L3_NO2_solar_azimuth_angle  \
# 0                   38.634284                  -61.736719
# 1                   59.624912                  -67.693509
# 2                   49.839714                  -78.342701
# 3                   29.180977                  -73.896572
# 4                    0.797294                  -68.612480
#
#    L3_NO2_solar_zenith_angle  L3_NO2_stratospheric_NO2_column_number_density  \
# 0                  22.358167                                        0.000057
# 1                  28.614804                                        0.000055
# 2                  34.296977                                        0.000059
# 3                  30.545393                                        0.000060
# 4                  26.899694                                        0.000062
#
#    L3_NO2_tropopause_pressure  L3_NO2_tropospheric_NO2_column_number_density  \
# 0                 6156.074219                                       0.000017
# 1                 6156.074219                                       0.000021
# 2                 7311.869141                                       0.000007
# 3                11205.388333                                       0.000023
# 4                11205.372845                                       0.000009
#
#    L3_O3_O3_column_number_density  L3_O3_O3_effective_temperature  \
# 0                        0.119095                      234.151102
# 1                        0.115179                      233.313706
# 2                        0.115876                      232.233484
# 3                        0.141557                      230.936229
# 4                        0.126369                      232.499132
#
#    L3_O3_cloud_fraction  L3_O3_sensor_azimuth_angle  \
# 0              0.000000                   76.536426
# 1              0.059433                  -14.708036
# 2              0.082063                 -105.201338
# 3              0.121261                 -104.334066
# 4              0.037919                   58.850179
#
#    L3_O3_sensor_zenith_angle  L3_O3_solar_azimuth_angle  \
# 0                  38.593017                 -61.752587
# 1                  59.624912                 -67.693509
# 2                  49.839714                 -78.342701
# 3                  29.181258                 -73.896588
# 4                   0.797294                 -68.612480
#
#    L3_O3_solar_zenith_angle  L3_CO_CO_column_number_density  \
# 0                 22.363665                        0.021080
# 1                 28.614804                        0.022017
# 2                 34.296977                        0.020677
# 3                 30.545446                        0.021207
# 4                 26.899694                        0.037766
#
#    L3_CO_H2O_column_number_density  L3_CO_cloud_height  L3_CO_sensor_altitude  \
# 0                       883.332451          267.017184          840138.461052
# 1                      1148.985447           61.216687          841116.763051
# 2                      1109.347101          134.700335          841319.860448
# 3                      1061.570832          474.821444          841036.192900
# 4                      1044.247425          926.926310          840710.342206
#
#    L3_CO_sensor_azimuth_angle  L3_CO_sensor_zenith_angle  \
# 0                   74.543393                  38.622451
# 1                  -57.015200                  61.402626
# 2                 -103.494458                  49.924556
# 3                 -101.955931                  29.214970
# 4                   15.499573                   1.389085
#
#    L3_CO_solar_azimuth_angle  L3_CO_solar_zenith_angle  \
# 0                 -61.789016                 22.379054
# 1                 -74.457583                 33.089495
# 2                 -78.355069                 34.308941
# 3                 -73.914571                 30.544513
# 4                 -68.622851                 26.906207
#
#    L3_HCHO_HCHO_slant_column_number_density  L3_HCHO_cloud_fraction  \
# 0                                 -0.000010                0.000000
# 1                                  0.000114                0.059433
# 2                                  0.000027                0.082063
# 3                                  0.000023                0.121261
# 4                                  0.000037                0.037919
#
#    L3_HCHO_sensor_azimuth_angle  L3_HCHO_sensor_zenith_angle  \
# 0                     76.536426                    38.593017
# 1                    -14.708036                    59.624912
# 2                   -105.201338                    49.839714
# 3                   -104.334066                    29.181258
# 4                     58.850179                     0.797294
#
#    L3_HCHO_solar_azimuth_angle  L3_HCHO_solar_zenith_angle  \
# 0                   -61.752587                   22.363665
# 1                   -67.693509                   28.614804
# 2                   -78.342701                   34.296977
# 3                   -73.896588                   30.545446
# 4                   -68.612480                   26.899694
#
#    L3_HCHO_tropospheric_HCHO_column_number_density  \
# 0                                         0.000064
# 1                                         0.000171
# 2                                         0.000124
# 3                                         0.000081
# 4                                         0.000140
#
#    L3_HCHO_tropospheric_HCHO_column_number_density_amf  \
# 0                                           0.566828
# 1                                           0.858446
# 2                                           0.910536
# 3                                           1.132571
# 4                                           0.649359
#
#    L3_CLOUD_cloud_base_height  L3_CLOUD_cloud_base_pressure  \
# 0                         NaN                           NaN
# 1                  175.019862                  99354.162958
# 2                  275.903991                  98118.935248
# 3                  383.692363                  97258.462755
# 4                 4314.483127                  59875.027957
#
#    L3_CLOUD_cloud_fraction  L3_CLOUD_cloud_optical_depth  \
# 0                 0.000000                           NaN
# 1                 0.059358                      5.958538
# 2                 0.082247                      5.755760
# 3                 0.121555                      6.246885
# 4                 0.037008                      4.205691
#
#    L3_CLOUD_cloud_top_height  L3_CLOUD_cloud_top_pressure  \
# 0                        NaN                          NaN
# 1                 175.072145                 99353.672374
# 2                 508.977723                 95671.383578
# 3                 495.380407                 96232.486418
# 4                5314.483207                 52561.523079
#
#    L3_CLOUD_sensor_azimuth_angle  L3_CLOUD_sensor_zenith_angle  \
# 0                      76.536426                     38.593017
# 1                     -14.708036                     59.624912
# 2                    -105.201338                     49.839714
# 3                    -104.334066                     29.181258
# 4                      58.850179                      0.797294
#
#    L3_CLOUD_solar_azimuth_angle  L3_CLOUD_solar_zenith_angle  \
# 0                    -61.752587                    22.363665
# 1                    -67.693509                    28.614804
# 2                    -78.342701                    34.296977
# 3                    -73.896588                    30.545446
# 4                    -68.612480                    26.899694
#
#    L3_CLOUD_surface_albedo  L3_AER_AI_absorbing_aerosol_index  \
# 0                      NaN                          -1.231330
# 1                 0.315403                          -1.082553
# 2                 0.307463                          -1.001241
# 3                 0.279637                          -0.777023
# 4                 0.238241                           0.366324
#
#    L3_AER_AI_sensor_altitude  L3_AER_AI_sensor_azimuth_angle  \
# 0              840209.874619                       76.537512
# 1              840772.941995                      -14.708036
# 2              841410.713456                     -105.201338
# 3              841103.242368                     -104.334056
# 4              840763.055499                       58.850179
#
#    L3_AER_AI_sensor_zenith_angle  L3_AER_AI_solar_azimuth_angle  \
# 0                      38.634284                     -61.736719
# 1                      59.624912                     -67.693509
# 2                      49.839714                     -78.342701
# 3                      29.180977                     -73.896572
# 4                       0.797294                     -68.612480
#
#    L3_AER_AI_solar_zenith_angle  L3_SO2_SO2_column_number_density  \
# 0                     22.358167                         -0.000127
# 1                     28.614804                          0.000150
# 2                     34.296977                          0.000150
# 3                     30.545393                          0.000227
# 4                     26.899694                          0.000390
#
#    L3_SO2_SO2_column_number_density_amf  \
# 0                              0.312521
# 1                              0.433957
# 2                              0.356925
# 3                              0.584522
# 4                              0.408047
#
#    L3_SO2_SO2_slant_column_number_density  L3_SO2_absorbing_aerosol_index  \
# 0                               -0.000040                       -1.861476
# 1                                0.000050                       -1.452612
# 2                                0.000053                       -1.572950
# 3                                0.000110                       -1.239317
# 4                                0.000159                        0.202489
#
#    L3_SO2_cloud_fraction  L3_SO2_sensor_azimuth_angle  \
# 0               0.000000                    76.536426
# 1               0.059433                   -14.708036
# 2               0.082063                  -105.201338
# 3               0.121261                  -104.334066
# 4               0.037919                    58.850179
#
#    L3_SO2_sensor_zenith_angle  L3_SO2_solar_azimuth_angle  \
# 0                   38.593017                  -61.752587
# 1                   59.624912                  -67.693509
# 2                   49.839714                  -78.342701
# 3                   29.181258                  -73.896588
# 4                    0.797294                  -68.612480
#
#    L3_SO2_solar_zenith_angle  L3_CH4_CH4_column_volume_mixing_ratio_dry_air  \
# 0                  22.363665                                    1793.793579
# 1                  28.614804                                    1789.960449
# 2                  34.296977                                            NaN
# 3                  30.545446                                            NaN
# 4                  26.899694                                            NaN
#
#    L3_CH4_aerosol_height  L3_CH4_aerosol_optical_depth  \
# 0            3227.855469                      0.010579
# 1            3384.226562                      0.015104
# 2                    NaN                           NaN
# 3                    NaN                           NaN
# 4                    NaN                           NaN
#
#    L3_CH4_sensor_azimuth_angle  L3_CH4_sensor_zenith_angle  \
# 0                    74.481049                   37.501499
# 1                    75.630043                   55.657486
# 2                          NaN                         NaN
# 3                          NaN                         NaN
# 4                          NaN                         NaN
#
#    L3_CH4_solar_azimuth_angle  L3_CH4_solar_zenith_angle
# 0                  -62.142639                  22.545118
# 1                  -53.868134                  19.293652
# 2                         NaN                        NaN
# 3                         NaN                        NaN
# 4                         NaN                        NaN

# %%
df.shape
# Out:
# (30557, 82)

# %%
df.columns
# Out:
# Index(['Place_ID X Date', 'Date', 'Place_ID', 'target', 'target_min',
#        'target_max', 'target_variance', 'target_count',
#        'precipitable_water_entire_atmosphere',
#        'relative_humidity_2m_above_ground',
#        'specific_humidity_2m_above_ground', 'temperature_2m_above_ground',
#        'u_component_of_wind_10m_above_ground',
#        'v_component_of_wind_10m_above_ground',
#        'L3_NO2_NO2_column_number_density',
#        'L3_NO2_NO2_slant_column_number_density',
#        'L3_NO2_absorbing_aerosol_index', 'L3_NO2_cloud_fraction',
#        'L3_NO2_sensor_altitude', 'L3_NO2_sensor_azimuth_angle',
#        'L3_NO2_sensor_zenith_angle', 'L3_NO2_solar_azimuth_angle',
#        'L3_NO2_solar_zenith_angle',
#        'L3_NO2_stratospheric_NO2_column_number_density',
#        'L3_NO2_tropopause_pressure',
#        'L3_NO2_tropospheric_NO2_column_number_density',
#        'L3_O3_O3_column_number_density', 'L3_O3_O3_effective_temperature',
#        'L3_O3_cloud_fraction', 'L3_O3_sensor_azimuth_angle',
#        'L3_O3_sensor_zenith_angle', 'L3_O3_solar_azimuth_angle',
#        'L3_O3_solar_zenith_angle', 'L3_CO_CO_column_number_density',
#        'L3_CO_H2O_column_number_density', 'L3_CO_cloud_height',
#        'L3_CO_sensor_altitude', 'L3_CO_sensor_azimuth_angle',
#        'L3_CO_sensor_zenith_angle', 'L3_CO_solar_azimuth_angle',
#        'L3_CO_solar_zenith_angle', 'L3_HCHO_HCHO_slant_column_number_density',
#        'L3_HCHO_cloud_fraction', 'L3_HCHO_sensor_azimuth_angle',
#        'L3_HCHO_sensor_zenith_angle', 'L3_HCHO_solar_azimuth_angle',
#        'L3_HCHO_solar_zenith_angle',
#        'L3_HCHO_tropospheric_HCHO_column_number_density',
#        'L3_HCHO_tropospheric_HCHO_column_number_density_amf',
#        'L3_CLOUD_cloud_base_height', 'L3_CLOUD_cloud_base_pressure',
#        'L3_CLOUD_cloud_fraction', 'L3_CLOUD_cloud_optical_depth',
#        'L3_CLOUD_cloud_top_height', 'L3_CLOUD_cloud_top_pressure',
#        'L3_CLOUD_sensor_azimuth_angle', 'L3_CLOUD_sensor_zenith_angle',
#        'L3_CLOUD_solar_azimuth_angle', 'L3_CLOUD_solar_zenith_angle',
#        'L3_CLOUD_surface_albedo', 'L3_AER_AI_absorbing_aerosol_index',
#        'L3_AER_AI_sensor_altitude', 'L3_AER_AI_sensor_azimuth_angle',
#        'L3_AER_AI_sensor_zenith_angle', 'L3_AER_AI_solar_azimuth_angle',
#        'L3_AER_AI_solar_zenith_angle', 'L3_SO2_SO2_column_number_density',
#        'L3_SO2_SO2_column_number_density_amf',
#        'L3_SO2_SO2_slant_column_number_density',
#        'L3_SO2_absorbing_aerosol_index', 'L3_SO2_cloud_fraction',
#        'L3_SO2_sensor_azimuth_angle', 'L3_SO2_sensor_zenith_angle',
#        'L3_SO2_solar_azimuth_angle', 'L3_SO2_solar_zenith_angle',
#        'L3_CH4_CH4_column_volume_mixing_ratio_dry_air',
#        'L3_CH4_aerosol_height', 'L3_CH4_aerosol_optical_depth',
#        'L3_CH4_sensor_azimuth_angle', 'L3_CH4_sensor_zenith_angle',
#        'L3_CH4_solar_azimuth_angle', 'L3_CH4_solar_zenith_angle'],
#       dtype='object')

# %%
# check for duplicate rows
duplicate_rows_df = df[df.duplicated()]
duplicate_rows_df
# Out:
# Empty DataFrame
# Columns: [Place_ID X Date, Date, Place_ID, target, target_min, target_max, target_variance, target_count, precipitable_water_entire_atmosphere, relative_humidity_2m_above_ground, specific_humidity_2m_above_ground, temperature_2m_above_ground, u_component_of_wind_10m_above_ground, v_component_of_wind_10m_above_ground, L3_NO2_NO2_column_number_density, L3_NO2_NO2_slant_column_number_density, L3_NO2_absorbing_aerosol_index, L3_NO2_cloud_fraction, L3_NO2_sensor_altitude, L3_NO2_sensor_azimuth_angle, L3_NO2_sensor_zenith_angle, L3_NO2_solar_azimuth_angle, L3_NO2_solar_zenith_angle, L3_NO2_stratospheric_NO2_column_number_density, L3_NO2_tropopause_pressure, L3_NO2_tropospheric_NO2_column_number_density, L3_O3_O3_column_number_density, L3_O3_O3_effective_temperature, L3_O3_cloud_fraction, L3_O3_sensor_azimuth_angle, L3_O3_sensor_zenith_angle, L3_O3_solar_azimuth_angle, L3_O3_solar_zenith_angle, L3_CO_CO_column_number_density, L3_CO_H2O_column_number_density, L3_CO_cloud_height, L3_CO_sensor_altitude, L3_CO_sensor_azimuth_angle, L3_CO_sensor_zenith_angle, L3_CO_solar_azimuth_angle, L3_CO_solar_zenith_angle, L3_HCHO_HCHO_slant_column_number_density, L3_HCHO_cloud_fraction, L3_HCHO_sensor_azimuth_angle, L3_HCHO_sensor_zenith_angle, L3_HCHO_solar_azimuth_angle, L3_HCHO_solar_zenith_angle, L3_HCHO_tropospheric_HCHO_column_number_density, L3_HCHO_tropospheric_HCHO_column_number_density_amf, L3_CLOUD_cloud_base_height, L3_CLOUD_cloud_base_pressure, L3_CLOUD_cloud_fraction, L3_CLOUD_cloud_optical_depth, L3_CLOUD_cloud_top_height, L3_CLOUD_cloud_top_pressure, L3_CLOUD_sensor_azimuth_angle, L3_CLOUD_sensor_zenith_angle, L3_CLOUD_solar_azimuth_angle, L3_CLOUD_solar_zenith_angle, L3_CLOUD_surface_albedo, L3_AER_AI_absorbing_aerosol_index, L3_AER_AI_sensor_altitude, L3_AER_AI_sensor_azimuth_angle, L3_AER_AI_sensor_zenith_angle, L3_AER_AI_solar_azimuth_angle, L3_AER_AI_solar_zenith_angle, L3_SO2_SO2_column_number_density, L3_SO2_SO2_column_number_density_amf, L3_SO2_SO2_slant_column_number_density, L3_SO2_absorbing_aerosol_index, L3_SO2_cloud_fraction, L3_SO2_sensor_azimuth_angle, L3_SO2_sensor_zenith_angle, L3_SO2_solar_azimuth_angle, L3_SO2_solar_zenith_angle, L3_CH4_CH4_column_volume_mixing_ratio_dry_air, L3_CH4_aerosol_height, L3_CH4_aerosol_optical_depth, L3_CH4_sensor_azimuth_angle, L3_CH4_sensor_zenith_angle, L3_CH4_solar_azimuth_angle, L3_CH4_solar_zenith_angle]
# Index: []

# %%
# Check for number of unique elements under each category
df.apply('nunique')
# Out:
# Place_ID X Date                 30557
# Date                               94
# Place_ID                          340
# target                            375
# target_min                        269
#                                 ...
# L3_CH4_aerosol_optical_depth     2874
# L3_CH4_sensor_azimuth_angle      2874
# L3_CH4_sensor_zenith_angle       2874
# L3_CH4_solar_azimuth_angle       2874
# L3_CH4_solar_zenith_angle        2874
# Length: 82, dtype: int64

# %%
# Check for zeros in data
df.isin([0]).sum().sort_values(ascending=False).head(10)
# Out:
# L3_CH4_solar_zenith_angle                        2915
# L3_CH4_sensor_zenith_angle                       2915
# L3_CH4_sensor_azimuth_angle                      2915
# L3_CH4_aerosol_optical_depth                     2915
# L3_CH4_aerosol_height                            2915
# L3_CH4_CH4_column_volume_mixing_ratio_dry_air    2915
# L3_CH4_solar_azimuth_angle                       2915
# L3_NO2_cloud_fraction                            2897
# L3_NO2_sensor_zenith_angle                       2611
# L3_NO2_tropopause_pressure                       2611
# dtype: int64

# %%
print(df.isnull().sum().sort_values(ascending=False).head(10))
# Out:
# L3_CH4_solar_zenith_angle                          24765
# L3_CH4_solar_azimuth_angle                         24765
# L3_CH4_sensor_zenith_angle                         24765
# L3_CH4_sensor_azimuth_angle                        24765
# L3_CH4_aerosol_optical_depth                       24765
# L3_CH4_aerosol_height                              24765
# L3_CH4_CH4_column_volume_mixing_ratio_dry_air      24765
# L3_NO2_tropospheric_NO2_column_number_density       8669
# L3_HCHO_tropospheric_HCHO_column_number_density     7425
# L3_HCHO_solar_zenith_angle                          7425
# dtype: int64

# %%
#get rid of all CH4 columns because they don't have that much info - a lot of zeros and NaNs
df = df.drop([ 'L3_CH4_CH4_column_volume_mixing_ratio_dry_air',
       'L3_CH4_aerosol_height', 'L3_CH4_aerosol_optical_depth',
       'L3_CH4_sensor_azimuth_angle', 'L3_CH4_sensor_zenith_angle',
       'L3_CH4_solar_azimuth_angle', 'L3_CH4_solar_zenith_angle'], axis=1)

# %%
# Recheck number of zeros and NaNs
print(df.isin([0]).sum().sort_values(ascending=False).head(10))
print(df.isnull().sum().sort_values(ascending=False).head(10))
# Out:
# L3_NO2_cloud_fraction                             2897
# L3_NO2_tropopause_pressure                        2611
# L3_NO2_sensor_azimuth_angle                       2611
# L3_NO2_tropospheric_NO2_column_number_density     2611
# L3_NO2_stratospheric_NO2_column_number_density    2611
# L3_NO2_solar_zenith_angle                         2611
# L3_NO2_solar_azimuth_angle                        2611
# L3_NO2_sensor_zenith_angle                        2611
# L3_NO2_sensor_altitude                            2611
# L3_NO2_absorbing_aerosol_index                    2611
# dtype: int64
# L3_NO2_tropospheric_NO2_column_number_density          8669
# L3_HCHO_tropospheric_HCHO_column_number_density        7425
# L3_HCHO_tropospheric_HCHO_column_number_density_amf    7425
# L3_HCHO_solar_zenith_angle                             7425
# L3_HCHO_solar_azimuth_angle                            7425
# L3_HCHO_sensor_zenith_angle                            7425
# L3_HCHO_sensor_azimuth_angle                           7425
# L3_HCHO_cloud_fraction                                 7425
# L3_HCHO_HCHO_slant_column_number_density               7425
# L3_SO2_absorbing_aerosol_index                         7308
# dtype: int64

# %% [markdown]
# I will now investigate whether or not the zeros in the data are due to a lack of information or if it actually makes sense for the data to have values of 0. Taking a look at some of the observations with 0 value in L3_NO2_cloud_fraction (the column with the most 0s):

# %%
display(df[df.L3_NO2_cloud_fraction == 0].head(10))
# Out:
#           Place_ID X Date        Date Place_ID  target  target_min  \
# 86   010Q650 X 2020-03-28  2020-03-28  010Q650    54.0        27.0
# 87   010Q650 X 2020-03-29  2020-03-29  010Q650    50.0        31.0
# 88   010Q650 X 2020-03-30  2020-03-30  010Q650    29.0        19.0
# 89   010Q650 X 2020-03-31  2020-03-31  010Q650    48.0        23.0
# 90   010Q650 X 2020-04-01  2020-04-01  010Q650    58.0        35.0
# 91   010Q650 X 2020-04-02  2020-04-02  010Q650    59.0        51.0
# 92   010Q650 X 2020-04-03  2020-04-03  010Q650    61.0        52.0
# 93   010Q650 X 2020-04-04  2020-04-04  010Q650    45.0        25.0
# 176  05EC30X X 2020-03-28  2020-03-28  05EC30X    53.0        38.0
# 177  05EC30X X 2020-03-29  2020-03-29  05EC30X    50.0        13.0
#
#      target_max  target_variance  target_count  \
# 86         76.0          1978.48            83
# 87         67.0           977.09            92
# 88         55.0          1106.75            95
# 89         65.0          1496.32            92
# 90         73.0           600.52            92
# 91         73.0           261.12            96
# 92         69.0           210.58            96
# 93         62.0          1186.51            96
# 176       170.0         10759.70            22
# 177        85.0          3388.94            22
#
#      precipitable_water_entire_atmosphere  relative_humidity_2m_above_ground  \
# 86                              19.700001                          73.000000
# 87                              20.400000                          57.200001
# 88                              11.200000                          33.200001
# 89                               8.600000                          23.100000
# 90                               9.200000                          37.000000
# 91                               5.670641                          32.600002
# 92                               6.100000                          17.500000
# 93                               5.500000                          17.500000
# 176                              6.862500                          25.537501
# 177                             17.800000                          66.187499
#
#      specific_humidity_2m_above_ground  temperature_2m_above_ground  \
# 86                            0.008420                    16.191858
# 87                            0.006760                    16.571649
# 88                            0.004140                    17.455774
# 89                            0.002970                    17.846338
# 90                            0.004260                    16.304498
# 91                            0.003780                    16.280878
# 92                            0.002750                    20.962549
# 93                            0.002360                    18.627374
# 176                           0.002577                    12.088121
# 177                           0.007646                    14.000406
#
#      u_component_of_wind_10m_above_ground  \
# 86                               2.627944
# 87                               1.681426
# 88                               1.201460
# 89                               1.003415
# 90                               2.242351
# 91                               2.669397
# 92                               1.839441
# 93                               1.725432
# 176                             -5.354556
# 177                             -2.731074
#
#      v_component_of_wind_10m_above_ground  L3_NO2_NO2_column_number_density  \
# 86                              -0.196741                               0.0
# 87                               0.674067                               0.0
# 88                               3.086216                               0.0
# 89                               2.183135                               0.0
# 90                               2.130308                               0.0
# 91                               2.814363                               0.0
# 92                               1.578384                               0.0
# 93                               1.912161                               0.0
# 176                             -3.412991                               0.0
# 177                             -2.252183                               0.0
#
#      L3_NO2_NO2_slant_column_number_density  L3_NO2_absorbing_aerosol_index  \
# 86                                      0.0                             0.0
# 87                                      0.0                             0.0
# 88                                      0.0                             0.0
# 89                                      0.0                             0.0
# 90                                      0.0                             0.0
# 91                                      0.0                             0.0
# 92                                      0.0                             0.0
# 93                                      0.0                             0.0
# 176                                     0.0                             0.0
# 177                                     0.0                             0.0
#
#      L3_NO2_cloud_fraction  L3_NO2_sensor_altitude  \
# 86                     0.0                     0.0
# 87                     0.0                     0.0
# 88                     0.0                     0.0
# 89                     0.0                     0.0
# 90                     0.0                     0.0
# 91                     0.0                     0.0
# 92                     0.0                     0.0
# 93                     0.0                     0.0
# 176                    0.0                     0.0
# 177                    0.0                     0.0
#
#      L3_NO2_sensor_azimuth_angle  L3_NO2_sensor_zenith_angle  \
# 86                           0.0                         0.0
# 87                           0.0                         0.0
# 88                           0.0                         0.0
# 89                           0.0                         0.0
# 90                           0.0                         0.0
# 91                           0.0                         0.0
# 92                           0.0                         0.0
# 93                           0.0                         0.0
# 176                          0.0                         0.0
# 177                          0.0                         0.0
#
#      L3_NO2_solar_azimuth_angle  L3_NO2_solar_zenith_angle  \
# 86                          0.0                        0.0
# 87                          0.0                        0.0
# 88                          0.0                        0.0
# 89                          0.0                        0.0
# 90                          0.0                        0.0
# 91                          0.0                        0.0
# 92                          0.0                        0.0
# 93                          0.0                        0.0
# 176                         0.0                        0.0
# 177                         0.0                        0.0
#
#      L3_NO2_stratospheric_NO2_column_number_density  \
# 86                                              0.0
# 87                                              0.0
# 88                                              0.0
# 89                                              0.0
# 90                                              0.0
# 91                                              0.0
# 92                                              0.0
# 93                                              0.0
# 176                                             0.0
# 177                                             0.0
#
#      L3_NO2_tropopause_pressure  \
# 86                          0.0
# 87                          0.0
# 88                          0.0
# 89                          0.0
# 90                          0.0
# 91                          0.0
# 92                          0.0
# 93                          0.0
# 176                         0.0
# 177                         0.0
#
#      L3_NO2_tropospheric_NO2_column_number_density  \
# 86                                             0.0
# 87                                             0.0
# 88                                             0.0
# 89                                             0.0
# 90                                             0.0
# 91                                             0.0
# 92                                             0.0
# 93                                             0.0
# 176                                            0.0
# 177                                            0.0
#
#      L3_O3_O3_column_number_density  L3_O3_O3_effective_temperature  \
# 86                         0.113733                      231.170874
# 87                         0.113769                      230.689257
# 88                         0.111579                      231.350736
# 89                         0.108725                      230.823419
# 90                         0.110478                      230.469471
# 91                              NaN                             NaN
# 92                         0.000000                        0.000000
# 93                         0.000000                        0.000000
# 176                        0.116821                      230.340391
# 177                        0.115359                      229.597428
#
#      L3_O3_cloud_fraction  L3_O3_sensor_azimuth_angle  \
# 86               0.271540                   -4.240685
# 87               0.128049                  -13.681473
# 88               0.082988                 -104.557370
# 89               0.013337                 -104.119412
# 90               0.000000                   76.275282
# 91                    NaN                         NaN
# 92               0.000000                    0.000000
# 93               0.000000                    0.000000
# 176              0.158739                  -14.079664
# 177              0.519682                 -103.603201
#
#      L3_O3_sensor_zenith_angle  L3_O3_solar_azimuth_angle  \
# 86                   57.759226                 -39.590673
# 87                   59.674360                 -35.610490
# 88                   37.290817                 -45.749798
# 89                   10.169529                 -40.440034
# 90                   21.307825                 -34.766504
# 91                         NaN                        NaN
# 92                    0.000000                   0.000000
# 93                    0.000000                   0.000000
# 176                  62.103631                 -41.355612
# 177                  51.597670                 -51.796852
#
#      L3_O3_solar_zenith_angle  L3_CO_CO_column_number_density  \
# 86                  48.292916                        0.020893
# 87                  47.173387                        0.019910
# 88                  50.692152                        0.021679
# 89                  48.432810                        0.020526
# 90                  46.465054                        0.019660
# 91                        NaN                             NaN
# 92                   0.000000                        0.000000
# 93                   0.000000                             NaN
# 176                 42.696392                        0.022794
# 177                 47.059567                        0.025311
#
#      L3_CO_H2O_column_number_density  L3_CO_cloud_height  \
# 86                       1352.145788         1396.235912
# 87                        959.620819          100.895999
# 88                        609.429284          525.870655
# 89                        868.025613           66.421979
# 90                        457.508121          257.454698
# 91                               NaN                 NaN
# 92                          0.000000            0.000000
# 93                               NaN                 NaN
# 176                      1016.953038         1043.471652
# 177                      2588.408774         3055.766849
#
#      L3_CO_sensor_altitude  L3_CO_sensor_azimuth_angle  \
# 86           839787.115499                   75.284695
# 87           839862.618281                   31.127966
# 88           841101.387949                 -102.571374
# 89           840799.010034                  -97.868184
# 90           840422.539129                   73.126599
# 91                     NaN                         NaN
# 92                0.000000                    0.000000
# 93                     NaN                         NaN
# 176          837676.459543                    5.844606
# 177          838612.089912                 -101.907913
#
#      L3_CO_sensor_zenith_angle  L3_CO_solar_azimuth_angle  \
# 86                   51.401343                 -27.242068
# 87                   62.309884                 -28.063348
# 88                   37.372516                 -45.764283
# 89                   10.246771                 -40.451338
# 90                   21.355483                 -34.781504
# 91                         NaN                        NaN
# 92                    0.000000                   0.000000
# 93                         NaN                        NaN
# 176                  61.433276                 -37.961011
# 177                  51.651506                 -51.811776
#
#      L3_CO_solar_zenith_angle  L3_HCHO_HCHO_slant_column_number_density  \
# 86                  42.298248                                  0.000066
# 87                  44.194501                                  0.000063
# 88                  50.700694                                  0.000014
# 89                  48.437156                                  0.000030
# 90                  46.469862                                  0.000057
# 91                        NaN                                       NaN
# 92                   0.000000                                  0.000000
# 93                        NaN                                       NaN
# 176                 41.035443                                  0.000061
# 177                 47.046902                                 -0.000107
#
#      L3_HCHO_cloud_fraction  L3_HCHO_sensor_azimuth_angle  \
# 86                 0.269066                     -4.239497
# 87                 0.128049                    -13.681473
# 88                 0.082988                   -104.557370
# 89                 0.013337                   -104.119412
# 90                 0.000000                     76.275282
# 91                      NaN                           NaN
# 92                 0.000000                      0.000000
# 93                      NaN                           NaN
# 176                0.158739                    -14.079664
# 177                0.368580                   -103.617996
#
#      L3_HCHO_sensor_zenith_angle  L3_HCHO_solar_azimuth_angle  \
# 86                     57.758086                   -39.590454
# 87                     59.674360                   -35.610490
# 88                     37.290817                   -45.749798
# 89                     10.169529                   -40.440034
# 90                     21.307825                   -34.766504
# 91                           NaN                          NaN
# 92                      0.000000                     0.000000
# 93                           NaN                          NaN
# 176                    62.103631                   -41.355612
# 177                    51.538260                   -51.749568
#
#      L3_HCHO_solar_zenith_angle  \
# 86                    48.290744
# 87                    47.173387
# 88                    50.692152
# 89                    48.432810
# 90                    46.465054
# 91                          NaN
# 92                     0.000000
# 93                          NaN
# 176                   42.696392
# 177                   47.106061
#
#      L3_HCHO_tropospheric_HCHO_column_number_density  \
# 86                                          0.000143
# 87                                          0.000164
# 88                                          0.000103
# 89                                          0.000127
# 90                                          0.000222
# 91                                               NaN
# 92                                          0.000000
# 93                                               NaN
# 176                                         0.000122
# 177                                        -0.000290
#
#      L3_HCHO_tropospheric_HCHO_column_number_density_amf  \
# 86                                            0.519249
# 87                                            0.706256
# 88                                            0.546205
# 89                                            0.568410
# 90                                            0.612827
# 91                                                 NaN
# 92                                            0.000000
# 93                                                 NaN
# 176                                           1.184456
# 177                                           0.754184
#
#      L3_CLOUD_cloud_base_height  L3_CLOUD_cloud_base_pressure  \
# 86                  4889.302151                  57160.511136
# 87                  1374.645718                  87108.965295
# 88                  2707.481437                  73948.463956
# 89                  5249.457732                  53507.791785
# 90                          NaN                           NaN
# 91                  4270.897977                  61214.687552
# 92                  4251.050644                  62602.172123
# 93                          NaN                           NaN
# 176                 1383.511530                  86196.735582
# 177                 4167.880925                  63156.853584
#
#      L3_CLOUD_cloud_fraction  L3_CLOUD_cloud_optical_depth  \
# 86                  0.275129                     10.183423
# 87                  0.125783                      4.656796
# 88                  0.083122                      4.455179
# 89                  0.012644                      4.305099
# 90                  0.000000                           NaN
# 91                  0.064139                      4.132446
# 92                  0.221391                      5.214410
# 93                       NaN                           NaN
# 176                 0.160725                      6.253106
# 177                 0.535998                     21.179879
#
#      L3_CLOUD_cloud_top_height  L3_CLOUD_cloud_top_pressure  \
# 86                 5889.302189                 50234.682138
# 87                 1876.521387                 82731.839780
# 88                 3707.481433                 65404.090844
# 89                 6249.457732                 46919.338817
# 90                         NaN                          NaN
# 91                 5270.898044                 53938.075667
# 92                 5251.050660                 55225.193544
# 93                         NaN                          NaN
# 176                1421.085692                 85835.453151
# 177                5125.560984                 56109.351982
#
#      L3_CLOUD_sensor_azimuth_angle  L3_CLOUD_sensor_zenith_angle  \
# 86                       -4.240685                     57.759226
# 87                      -13.681473                     59.674360
# 88                     -104.557370                     37.290817
# 89                     -104.119412                     10.169529
# 90                       76.275282                     21.307825
# 91                       76.737564                     45.417097
# 92                      -14.204020                     59.923859
# 93                             NaN                           NaN
# 176                     -14.079664                     62.103631
# 177                    -103.603201                     51.597670
#
#      L3_CLOUD_solar_azimuth_angle  L3_CLOUD_solar_zenith_angle  \
# 86                     -39.590673                    48.292916
# 87                     -35.610490                    47.173387
# 88                     -45.749798                    50.692152
# 89                     -40.440034                    48.432810
# 90                     -34.766504                    46.465054
# 91                     -28.723104                    44.828765
# 92                     -36.711852                    49.737255
# 93                            NaN                          NaN
# 176                    -41.355612                    42.696392
# 177                    -51.796852                    47.059567
#
#      L3_CLOUD_surface_albedo  L3_AER_AI_absorbing_aerosol_index  \
# 86                  0.250742                          -0.835711
# 87                  0.220840                          -0.952558
# 88                  0.234848                          -1.033154
# 89                  0.215728                          -1.094245
# 90                       NaN                          -1.052791
# 91                  0.195341                          -2.067149
# 92                  0.219988                          -0.810711
# 93                       NaN                                NaN
# 176                 0.305123                          -1.319078
# 177                 0.309830                          -0.680543
#
#      L3_AER_AI_sensor_altitude  L3_AER_AI_sensor_azimuth_angle  \
# 86               840756.717048                       -4.240685
# 87               840483.641615                      -13.681473
# 88               841171.352234                     -104.557370
# 89               840852.784976                     -104.119412
# 90               840480.191495                       76.275282
# 91               840047.183461                       76.735186
# 92               840624.019710                      -14.204020
# 93                         NaN                             NaN
# 176              838018.417436                      -14.079664
# 177              838702.746810                     -103.599104
#
#      L3_AER_AI_sensor_zenith_angle  L3_AER_AI_solar_azimuth_angle  \
# 86                       57.759226                     -39.590673
# 87                       59.674360                     -35.610490
# 88                       37.290817                     -45.749798
# 89                       10.169529                     -40.440034
# 90                       21.307825                     -34.766504
# 91                       45.365528                     -28.740996
# 92                       59.923859                     -36.711852
# 93                             NaN                            NaN
# 176                      62.103631                     -41.355612
# 177                      51.629663                     -51.815403
#
#      L3_AER_AI_solar_zenith_angle  L3_SO2_SO2_column_number_density  \
# 86                      48.292916                          0.000137
# 87                      47.173387                         -0.000305
# 88                      50.692152                          0.000069
# 89                      48.432810                         -0.000020
# 90                      46.465054                         -0.000042
# 91                      44.829271                               NaN
# 92                      49.737255                          0.000000
# 93                            NaN                         -0.000258
# 176                     42.696392                          0.000055
# 177                     47.047285                         -0.000152
#
#      L3_SO2_SO2_column_number_density_amf  \
# 86                               0.310367
# 87                               0.438089
# 88                               0.380430
# 89                               0.461267
# 90                               0.327923
# 91                                    NaN
# 92                               0.000000
# 93                               0.420484
# 176                              0.610368
# 177                              0.386500
#
#      L3_SO2_SO2_slant_column_number_density  L3_SO2_absorbing_aerosol_index  \
# 86                                -0.000029                       -1.251251
# 87                                -0.000129                       -1.371859
# 88                                 0.000027                       -1.723197
# 89                                -0.000009                       -1.752573
# 90                                -0.000013                       -1.777798
# 91                                      NaN                             NaN
# 92                                 0.000000                        0.000000
# 93                                -0.000114                       -1.614484
# 176                                0.000037                       -1.801153
# 177                               -0.000065                       -1.369630
#
#      L3_SO2_cloud_fraction  L3_SO2_sensor_azimuth_angle  \
# 86                0.271540                    -4.240685
# 87                0.128049                   -13.681473
# 88                0.082988                  -104.557370
# 89                0.013337                  -104.119412
# 90                0.000000                    76.275282
# 91                     NaN                          NaN
# 92                0.000000                     0.000000
# 93                0.119285                  -104.845225
# 176               0.158739                   -14.079664
# 177               0.368580                  -103.617996
#
#      L3_SO2_sensor_zenith_angle  L3_SO2_solar_azimuth_angle  \
# 86                    57.759226                  -39.590673
# 87                    59.674360                  -35.610490
# 88                    37.290817                  -45.749798
# 89                    10.169529                  -40.440034
# 90                    21.307825                  -34.766504
# 91                          NaN                         NaN
# 92                     0.000000                    0.000000
# 93                    44.105635                  -46.289380
# 176                   62.103631                  -41.355612
# 177                   51.538260                  -51.749568
#
#      L3_SO2_solar_zenith_angle
# 86                   48.292916
# 87                   47.173387
# 88                   50.692152
# 89                   48.432810
# 90                   46.465054
# 91                         NaN
# 92                    0.000000
# 93                   53.377209
# 176                  42.696392
# 177                  47.106061

# %% [markdown]
# It looks like there is a consistent theme for the data above: the NO2 data is all 0s or missing entirely. Doing a little research into what each of the terms mean, columns such as the one representing tropospheric pressure cannot be zero and it is highly unlikely for column density to be 0 (pretty much impossible). I think that zeros are therefore representative of missing information, and will now replace the 0s with NaNs to prevent misreading information.

# %%
df.replace(0, np.nan, inplace=True)
df.isin([0]).sum().sort_values(ascending=False)
# Out:
# L3_SO2_solar_zenith_angle       0
# L3_NO2_sensor_altitude          0
# L3_NO2_sensor_zenith_angle      0
# L3_NO2_solar_azimuth_angle      0
# L3_NO2_solar_zenith_angle       0
#                                ..
# L3_CLOUD_cloud_base_pressure    0
# L3_CLOUD_cloud_fraction         0
# L3_CLOUD_cloud_optical_depth    0
# L3_CLOUD_cloud_top_height       0
# Place_ID X Date                 0
# Length: 75, dtype: int64

# %%
print(df.isnull().sum().sort_values(ascending=False).head(10))
# Out:
# L3_NO2_tropospheric_NO2_column_number_density          11280
# L3_HCHO_cloud_fraction                                  8773
# L3_SO2_cloud_fraction                                   8563
# L3_HCHO_tropospheric_HCHO_column_number_density         7755
# L3_HCHO_tropospheric_HCHO_column_number_density_amf     7755
# L3_HCHO_solar_zenith_angle                              7755
# L3_HCHO_solar_azimuth_angle                             7755
# L3_HCHO_sensor_zenith_angle                             7755
# L3_HCHO_sensor_azimuth_angle                            7755
# L3_HCHO_HCHO_slant_column_number_density                7755
# dtype: int64

# %%
# Find out how much data there is that do not have null values
df.dropna(how='any',inplace= True)
df.shape
# Out:
# (16383, 75)

# %% [markdown]
# After dropping null values, the number of observations dropped from 30557 to 16311 (a little over 50%).

# %% [markdown]
# It appears that the information in the Place_ID X Date column is represented by the Date and Place_ID columns, thus we can drop this column.

# %%
df = df.drop(['Place_ID X Date'], axis=1)

# %%
# Check datatypes of each row
df.dtypes
# Out:
# Date                            object
# Place_ID                        object
# target                         float64
# target_min                     float64
# target_max                     float64
#                                 ...
# L3_SO2_cloud_fraction          float64
# L3_SO2_sensor_azimuth_angle    float64
# L3_SO2_sensor_zenith_angle     float64
# L3_SO2_solar_azimuth_angle     float64
# L3_SO2_solar_zenith_angle      float64
# Length: 74, dtype: object

# %%
# The datatype of date column is currently object. Converting to datetime:
df['Date'] = df['Date'].astype('datetime64')

# %% [markdown]
# Since there are too many columns to check the datatypes of, I will check to see if there are any categorical variables that need to be converted into numerical variables that can be used during modelling.

# %%
df.select_dtypes(exclude=['float64'])
# Out:
#             Date Place_ID  target_count
# 1     2020-01-03  010Q650            91
# 2     2020-01-04  010Q650            96
# 3     2020-01-05  010Q650            96
# 4     2020-01-06  010Q650            95
# 5     2020-01-07  010Q650            94
# ...          ...      ...           ...
# 30551 2020-03-14  YWSFY6Q            72
# 30552 2020-03-15  YWSFY6Q            72
# 30553 2020-03-16  YWSFY6Q            72
# 30554 2020-03-17  YWSFY6Q            72
# 30555 2020-03-18  YWSFY6Q            72
#
# [16383 rows x 3 columns]

# %% [markdown]
# Looks like Place_ID is the only relevant column, lets transform it.

# %%
codes, uniques = pd.factorize(df['Place_ID'])
df.insert(7, 'Location', codes)
display(df.head())
# Out:
#         Date Place_ID  target  target_min  target_max  target_variance  \
# 1 2020-01-03  010Q650    39.0        25.0        63.0          1319.85
# 2 2020-01-04  010Q650    24.0         8.0        56.0          1181.96
# 3 2020-01-05  010Q650    49.0        10.0        55.0          1113.67
# 4 2020-01-06  010Q650    21.0         9.0        52.0          1164.82
# 5 2020-01-07  010Q650    28.0        10.0        52.0          1053.22
#
#    target_count  Location  precipitable_water_entire_atmosphere  \
# 1            91         0                             14.600000
# 2            96         0                             16.400000
# 3            96         0                              6.911948
# 4            95         0                             13.900001
# 5            94         0                             14.600000
#
#    relative_humidity_2m_above_ground  specific_humidity_2m_above_ground  \
# 1                          48.799999                           0.008390
# 2                          33.400002                           0.007500
# 3                          21.300001                           0.003910
# 4                          44.700001                           0.005350
# 5                          42.200001                           0.005862
#
#    temperature_2m_above_ground  u_component_of_wind_10m_above_ground  \
# 1                    22.546533                              3.330430
# 2                    27.031030                              5.065727
# 3                    23.971857                              3.004001
# 4                    16.816309                              2.621787
# 5                    19.174890                              2.955603
#
#    v_component_of_wind_10m_above_ground  L3_NO2_NO2_column_number_density  \
# 1                             -1.188108                          0.000076
# 2                              3.500559                          0.000067
# 3                              1.099468                          0.000083
# 4                              2.670559                          0.000070
# 5                              0.969075                          0.000069
#
#    L3_NO2_NO2_slant_column_number_density  L3_NO2_absorbing_aerosol_index  \
# 1                                0.000197                       -1.082553
# 2                                0.000170                       -1.001242
# 3                                0.000175                       -0.777019
# 4                                0.000142                        0.366323
# 5                                0.000146                       -0.725329
#
#    L3_NO2_cloud_fraction  L3_NO2_sensor_altitude  L3_NO2_sensor_azimuth_angle  \
# 1               0.018360           840772.941995                   -14.708036
# 2               0.015904           841410.713456                  -105.201338
# 3               0.055765           841103.242368                  -104.334056
# 4               0.028530           840763.055499                    58.850179
# 5               0.070249           840356.873809                    76.387678
#
#    L3_NO2_sensor_zenith_angle  L3_NO2_solar_azimuth_angle  \
# 1                   59.624912                  -67.693509
# 2                   49.839714                  -78.342701
# 3                   29.180977                  -73.896572
# 4                    0.797294                  -68.612480
# 5                   30.606610                  -62.133340
#
#    L3_NO2_solar_zenith_angle  L3_NO2_stratospheric_NO2_column_number_density  \
# 1                  28.614804                                        0.000055
# 2                  34.296977                                        0.000059
# 3                  30.545393                                        0.000060
# 4                  26.899694                                        0.000062
# 5                  23.419985                                        0.000057
#
#    L3_NO2_tropopause_pressure  L3_NO2_tropospheric_NO2_column_number_density  \
# 1                 6156.074219                                       0.000021
# 2                 7311.869141                                       0.000007
# 3                11205.388333                                       0.000023
# 4                11205.372845                                       0.000009
# 5                11205.115564                                       0.000012
#
#    L3_O3_O3_column_number_density  L3_O3_O3_effective_temperature  \
# 1                        0.115179                      233.313706
# 2                        0.115876                      232.233484
# 3                        0.141557                      230.936229
# 4                        0.126369                      232.499132
# 5                        0.126138                      232.527580
#
#    L3_O3_cloud_fraction  L3_O3_sensor_azimuth_angle  \
# 1              0.059433                  -14.708036
# 2              0.082063                 -105.201338
# 3              0.121261                 -104.334066
# 4              0.037919                   58.850179
# 5              0.063836                   76.387658
#
#    L3_O3_sensor_zenith_angle  L3_O3_solar_azimuth_angle  \
# 1                  59.624912                 -67.693509
# 2                  49.839714                 -78.342701
# 3                  29.181258                 -73.896588
# 4                   0.797294                 -68.612480
# 5                  30.605176                 -62.134264
#
#    L3_O3_solar_zenith_angle  L3_CO_CO_column_number_density  \
# 1                 28.614804                        0.022017
# 2                 34.296977                        0.020677
# 3                 30.545446                        0.021207
# 4                 26.899694                        0.037766
# 5                 23.419991                        0.029486
#
#    L3_CO_H2O_column_number_density  L3_CO_cloud_height  L3_CO_sensor_altitude  \
# 1                      1148.985447           61.216687          841116.763051
# 2                      1109.347101          134.700335          841319.860448
# 3                      1061.570832          474.821444          841036.192900
# 4                      1044.247425          926.926310          840710.342206
# 5                      1503.566325         2288.723674          840292.142379
#
#    L3_CO_sensor_azimuth_angle  L3_CO_sensor_zenith_angle  \
# 1                  -57.015200                  61.402626
# 2                 -103.494458                  49.924556
# 3                 -101.955931                  29.214970
# 4                   15.499573                   1.389085
# 5                   74.053369                  30.652168
#
#    L3_CO_solar_azimuth_angle  L3_CO_solar_zenith_angle  \
# 1                 -74.457583                 33.089495
# 2                 -78.355069                 34.308941
# 3                 -73.914571                 30.544513
# 4                 -68.622851                 26.906207
# 5                 -62.160219                 23.429186
#
#    L3_HCHO_HCHO_slant_column_number_density  L3_HCHO_cloud_fraction  \
# 1                                  0.000114                0.059433
# 2                                  0.000027                0.082063
# 3                                  0.000023                0.121261
# 4                                  0.000037                0.037919
# 5                                  0.000009                0.063836
#
#    L3_HCHO_sensor_azimuth_angle  L3_HCHO_sensor_zenith_angle  \
# 1                    -14.708036                    59.624912
# 2                   -105.201338                    49.839714
# 3                   -104.334066                    29.181258
# 4                     58.850179                     0.797294
# 5                     76.387658                    30.605176
#
#    L3_HCHO_solar_azimuth_angle  L3_HCHO_solar_zenith_angle  \
# 1                   -67.693509                   28.614804
# 2                   -78.342701                   34.296977
# 3                   -73.896588                   30.545446
# 4                   -68.612480                   26.899694
# 5                   -62.134264                   23.419991
#
#    L3_HCHO_tropospheric_HCHO_column_number_density  \
# 1                                         0.000171
# 2                                         0.000124
# 3                                         0.000081
# 4                                         0.000140
# 5                                         0.000094
#
#    L3_HCHO_tropospheric_HCHO_column_number_density_amf  \
# 1                                           0.858446
# 2                                           0.910536
# 3                                           1.132571
# 4                                           0.649359
# 5                                           0.716104
#
#    L3_CLOUD_cloud_base_height  L3_CLOUD_cloud_base_pressure  \
# 1                  175.019862                  99354.162958
# 2                  275.903991                  98118.935248
# 3                  383.692363                  97258.462755
# 4                 4314.483127                  59875.027957
# 5                 3629.889961                  65606.261651
#
#    L3_CLOUD_cloud_fraction  L3_CLOUD_cloud_optical_depth  \
# 1                 0.059358                      5.958538
# 2                 0.082247                      5.755760
# 3                 0.121555                      6.246885
# 4                 0.037008                      4.205691
# 5                 0.065998                      4.608632
#
#    L3_CLOUD_cloud_top_height  L3_CLOUD_cloud_top_pressure  \
# 1                 175.072145                 99353.672374
# 2                 508.977723                 95671.383578
# 3                 495.380407                 96232.486418
# 4                5314.483207                 52561.523079
# 5                4629.889853                 57752.642640
#
#    L3_CLOUD_sensor_azimuth_angle  L3_CLOUD_sensor_zenith_angle  \
# 1                     -14.708036                     59.624912
# 2                    -105.201338                     49.839714
# 3                    -104.334066                     29.181258
# 4                      58.850179                      0.797294
# 5                      76.387658                     30.605176
#
#    L3_CLOUD_solar_azimuth_angle  L3_CLOUD_solar_zenith_angle  \
# 1                    -67.693509                    28.614804
# 2                    -78.342701                    34.296977
# 3                    -73.896588                    30.545446
# 4                    -68.612480                    26.899694
# 5                    -62.134264                    23.419991
#
#    L3_CLOUD_surface_albedo  L3_AER_AI_absorbing_aerosol_index  \
# 1                 0.315403                          -1.082553
# 2                 0.307463                          -1.001241
# 3                 0.279637                          -0.777023
# 4                 0.238241                           0.366324
# 5                 0.251568                          -0.723037
#
#    L3_AER_AI_sensor_altitude  L3_AER_AI_sensor_azimuth_angle  \
# 1              840772.941995                      -14.708036
# 2              841410.713456                     -105.201338
# 3              841103.242368                     -104.334056
# 4              840763.055499                       58.850179
# 5              840356.767649                       76.387658
#
#    L3_AER_AI_sensor_zenith_angle  L3_AER_AI_solar_azimuth_angle  \
# 1                      59.624912                     -67.693509
# 2                      49.839714                     -78.342701
# 3                      29.180977                     -73.896572
# 4                       0.797294                     -68.612480
# 5                      30.605176                     -62.134264
#
#    L3_AER_AI_solar_zenith_angle  L3_SO2_SO2_column_number_density  \
# 1                     28.614804                          0.000150
# 2                     34.296977                          0.000150
# 3                     30.545393                          0.000227
# 4                     26.899694                          0.000390
# 5                     23.419991                          0.000019
#
#    L3_SO2_SO2_column_number_density_amf  \
# 1                              0.433957
# 2                              0.356925
# 3                              0.584522
# 4                              0.408047
# 5                              0.441191
#
#    L3_SO2_SO2_slant_column_number_density  L3_SO2_absorbing_aerosol_index  \
# 1                                0.000050                       -1.452612
# 2                                0.000053                       -1.572950
# 3                                0.000110                       -1.239317
# 4                                0.000159                        0.202489
# 5                                0.000008                       -0.987820
#
#    L3_SO2_cloud_fraction  L3_SO2_sensor_azimuth_angle  \
# 1               0.059433                   -14.708036
# 2               0.082063                  -105.201338
# 3               0.121261                  -104.334066
# 4               0.037919                    58.850179
# 5               0.063836                    76.387658
#
#    L3_SO2_sensor_zenith_angle  L3_SO2_solar_azimuth_angle  \
# 1                   59.624912                  -67.693509
# 2                   49.839714                  -78.342701
# 3                   29.181258                  -73.896588
# 4                    0.797294                  -68.612480
# 5                   30.605176                  -62.134264
#
#    L3_SO2_solar_zenith_angle
# 1                  28.614804
# 2                  34.296977
# 3                  30.545446
# 4                  26.899694
# 5                  23.419991

# %% [markdown]
# We keep track of how to convert between the Location and the corresponding Place_ID by exporting this information into an excel file.

# %%
id_to_location = df[['Place_ID','Location']]
id_to_location.to_csv("id_to_location.csv", index=False)

# %%
# We can now safely drop the Place_ID column
df = df.drop(['Place_ID'], axis=1)

# %% [markdown]
# Looking at the data again, it appears as though the data can be broken down into mutually exclusive groups (data about NO2, data about aerosol, etc.) I think it would be useful to explore correlations between the target variable and each group of data.

# %%
target_variables = df.loc[:,'target':'target_count']
general = df.loc[:,'Location':'v_component_of_wind_10m_above_ground']
no2 = df.loc[:,'L3_NO2_NO2_column_number_density':'L3_NO2_tropospheric_NO2_column_number_density']
o3 = df.loc[:,'L3_O3_O3_column_number_density':'L3_O3_solar_zenith_angle']
co = df.loc[:,'L3_CO_CO_column_number_density':'L3_CO_solar_zenith_angle']
hcho = df.loc[:,'L3_HCHO_HCHO_slant_column_number_density':'L3_HCHO_tropospheric_HCHO_column_number_density_amf']
cloud = df.loc[:,'L3_CLOUD_cloud_base_height':'L3_CLOUD_surface_albedo']
aer = df.loc[:,'L3_AER_AI_absorbing_aerosol_index':'L3_AER_AI_solar_zenith_angle']
so2 = df.loc[:,'L3_SO2_SO2_column_number_density':'L3_SO2_solar_zenith_angle']
groups = [general, no2, o3, co, hcho, cloud, aer, so2]

# %%
from ipywidgets import interact, fixed

# %%
#Create our plotting function
def plot_heatmap(df1, df2):
    # plt.figure(figsize=(20,10))
    temp = pd.concat([df1, df2], axis=1)
    #corrmat = temp.corr()
    #corr = sns.heatmap(corrmat, cmap='coolwarm', annot=True)

# %%
interact(plot_heatmap, df1=fixed(target_variables), df2=groups);
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /opt/anaconda3/lib/python3.7/site-packages/ipywidgets/widgets/widget_selection.py in _validate_value(self, proposal)
#     240         try:
# --> 241             return findvalue(self._options_values, value, self.equals) if value is not None else None
#     242         except ValueError:
#
# /opt/anaconda3/lib/python3.7/site-packages/ipywidgets/widgets/widget_selection.py in findvalue(array, value, compare)
#     136     try:
# --> 137         return next(x for x in array if compare(x, value))
#     138     except StopIteration:
#
# /opt/anaconda3/lib/python3.7/site-packages/ipywidgets/widgets/widget_selection.py in <genexpr>(.0)
#     136     try:
# --> 137         return next(x for x in array if compare(x, value))
#     138     except StopIteration:
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __nonzero__(self)
#    1478         raise ValueError(
# -> 1479             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1480             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a DataFrame is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
#
# During handling of the above exception, another exception occurred:
#
# TraitError                                Traceback (most recent call last)
# <ipython-input-61-7655cfbf8412> in <module>
# ----> 1 interact(plot_heatmap, df1=fixed(target_variables), df2=groups);
#
# /opt/anaconda3/lib/python3.7/site-packages/ipywidgets/widgets/interaction.py in __call__(self, _InteractFactory__interact_f, **kwargs)
#     526         #    def f(*args, **kwargs):
#     527         #        ...
# --> 528         w = self.widget(f)
#     529         try:
#     530             f.widget = w
#
# /opt/anaconda3/lib/python3.7/site-packages/ipywidgets/widgets/interaction.py in widget(self, f)
#     442             The function to which the interactive widgets are tied.
#     443         """
# --> 444         return self.cls(f, self.opts, **self.kwargs)
#     445
#     446     def __call__(self, __interact_f=None, **kwargs):
#
# /opt/anaconda3/lib/python3.7/site-packages/ipywidgets/widgets/interaction.py in __init__(self, _interactive__interact_f, _interactive__options, **kwargs)
#     198             getcallargs(f, **{n:v for n,v,_ in new_kwargs})
#     199         # Now build the widgets from the abbreviations.
# --> 200         self.kwargs_widgets = self.widgets_from_abbreviations(new_kwargs)
#     201
#     202         # This has to be done as an assignment, not using self.children.append,
#
# /opt/anaconda3/lib/python3.7/site-packages/ipywidgets/widgets/interaction.py in widgets_from_abbreviations(self, seq)
#     295         result = []
#     296         for name, abbrev, default in seq:
# --> 297             widget = self.widget_from_abbrev(abbrev, default)
#     298             if not (isinstance(widget, ValueWidget) or isinstance(widget, fixed)):
#     299                 if widget is None:
#
# /opt/anaconda3/lib/python3.7/site-packages/ipywidgets/widgets/interaction.py in widget_from_abbrev(cls, abbrev, default)
#     331         # tuple should be handled before, that is why we check this case last.
#     332         if isinstance(abbrev, Iterable):
# --> 333             widget = cls.widget_from_iterable(abbrev)
#     334             if default is not empty:
#     335                 try:
#
# /opt/anaconda3/lib/python3.7/site-packages/ipywidgets/widgets/interaction.py in widget_from_iterable(o)
#     387         # iterable to either of those.
#     388         if isinstance(o, (list, dict)):
# --> 389             return Dropdown(options=o)
#     390         elif isinstance(o, Mapping):
#     391             return Dropdown(options=list(o.items()))
#
# /opt/anaconda3/lib/python3.7/site-packages/ipywidgets/widgets/widget_selection.py in __init__(self, *args, **kwargs)
#     188             kwargs['label'], kwargs['value'] = options[0] if nonempty else (None, None)
#     189
# --> 190         super(_Selection, self).__init__(*args, **kwargs)
#     191         self._initializing_traits_ = False
#     192
#
# /opt/anaconda3/lib/python3.7/site-packages/ipywidgets/widgets/widget.py in __init__(self, **kwargs)
#     410         """Public constructor"""
#     411         self._model_id = kwargs.pop('model_id', None)
# --> 412         super(Widget, self).__init__(**kwargs)
#     413
#     414         Widget._call_widget_constructed(self)
#
# /opt/anaconda3/lib/python3.7/site-packages/traitlets/traitlets.py in __init__(self, *args, **kwargs)
#     998                 else:
#     999                     # passthrough args that don't set traits to super
# -> 1000                     super_kwargs[key] = value
#    1001         try:
#    1002             super(HasTraits, self).__init__(*super_args, **super_kwargs)
#
# /opt/anaconda3/lib/python3.7/contextlib.py in __exit__(self, type, value, traceback)
#     117         if type is None:
#     118             try:
# --> 119                 next(self.gen)
#     120             except StopIteration:
#     121                 return False
#
# /opt/anaconda3/lib/python3.7/site-packages/traitlets/traitlets.py in hold_trait_notifications(self)
#    1120                                 self._trait_values.pop(name)
#    1121                 cache = {}
# -> 1122                 raise e
#    1123             finally:
#    1124                 self._cross_validation_lock = False
#
# /opt/anaconda3/lib/python3.7/site-packages/traitlets/traitlets.py in hold_trait_notifications(self)
#    1106                 for name in list(cache.keys()):
#    1107                     trait = getattr(self.__class__, name)
# -> 1108                     value = trait._cross_validate(self, getattr(self, name))
#    1109                     self.set_trait(name, value)
#    1110             except TraitError as e:
#
# /opt/anaconda3/lib/python3.7/site-packages/traitlets/traitlets.py in _cross_validate(self, obj, value)
#     597         if self.name in obj._trait_validators:
#     598             proposal = Bunch({'trait': self, 'value': value, 'owner': obj})
# --> 599             value = obj._trait_validators[self.name](obj, proposal)
#     600         elif hasattr(obj, '_%s_validate' % self.name):
#     601             meth_name = '_%s_validate' % self.name
#
# /opt/anaconda3/lib/python3.7/site-packages/traitlets/traitlets.py in __call__(self, *args, **kwargs)
#     905         """Pass `*args` and `**kwargs` to the handler's function if it exists."""
#     906         if hasattr(self, 'func'):
# --> 907             return self.func(*args, **kwargs)
#     908         else:
#     909             return self._init_call(*args, **kwargs)
#
# /opt/anaconda3/lib/python3.7/site-packages/ipywidgets/widgets/widget_selection.py in _validate_value(self, proposal)
#     241             return findvalue(self._options_values, value, self.equals) if value is not None else None
#     242         except ValueError:
# --> 243             raise TraitError('Invalid selection: value not found')
#     244
#     245     @observe('value')
#
# TraitError: Invalid selection: value not found

# %% [markdown]
# Let's take a closer look at all the columns with the prefix "target". According to the competition specs this information is not given in the "Test" data (thus we cannot use it in our model). However, I am interested in the relationship between these variables.

# %%
target_variables = ['target', 'target_min', 'target_max', 'target_variance', 'target_count']

# %%
plt.figure(figsize=(20,10))
corrmat = df[target_variables].corr()
corr = sns.heatmap(corrmat, cmap='coolwarm', annot=True)

# %% [markdown]
# It looks like target variance and target count (the number of sensor readings used to compute the target value) are inversely correlated (which makes sense, because the more data you have, the more precise

# %%
plt.figure(figsize=(20,10))
corrmat = df.corr()
corr = sns.heatmap(corrmat, cmap='coolwarm', annot=True)

# %%
df.describe()
# Out:
#              target   target_min    target_max  target_variance  target_count  \
# count  16383.000000  16383.00000  16383.000000     1.638300e+04  16383.000000
# mean      65.296863     32.02458    126.152768     8.985654e+03    121.877007
# std       48.792369     34.66054    107.293980     5.428274e+04    143.776717
# min        1.000000      1.00000      2.000000     1.090000e+00      2.000000
# 25%       29.000000      5.00000     63.000000     1.126760e+03     38.000000
# 50%       55.000000     17.00000     99.000000     2.629300e+03     72.000000
# 75%       87.000000     50.00000    159.000000     6.702235e+03    144.000000
# max      815.000000    274.00000    999.000000     1.841490e+06   1552.000000
#
#            Location  precipitable_water_entire_atmosphere  \
# count  16383.000000                          16383.000000
# mean     167.696271                             14.911322
# std       97.831444                             10.482081
# min        0.000000                              0.420044
# 25%       83.000000                              7.235417
# 50%      167.000000                             12.000000
# 75%      251.000000                             19.700001
# max      337.000000                             63.600002
#
#        relative_humidity_2m_above_ground  specific_humidity_2m_above_ground  \
# count                       16383.000000                       16383.000000
# mean                           67.776642                           0.006299
# std                            19.108605                           0.003985
# min                             5.128572                           0.000300
# 25%                            55.000000                           0.003412
# 50%                            70.700005                           0.005190
# 75%                            83.099998                           0.008265
# max                           100.000000                           0.021615
#
#        temperature_2m_above_ground  u_component_of_wind_10m_above_ground  \
# count                 16383.000000                          16383.000000
# mean                     10.434718                              0.442937
# std                       9.705877                              2.622377
# min                     -28.140352                            -14.188260
# 25%                       3.880518                             -0.991775
# 50%                      10.195158                              0.245283
# 75%                      18.140009                              1.700669
# max                      37.437921                             16.931971
#
#        v_component_of_wind_10m_above_ground  L3_NO2_NO2_column_number_density  \
# count                          16383.000000                      16383.000000
# mean                              -0.069289                          0.000102
# std                                2.512540                          0.000086
# min                              -15.023647                         -0.000013
# 25%                               -1.458789                          0.000062
# 50%                               -0.083521                          0.000079
# 75%                                1.323217                          0.000114
# max                               13.080090                          0.001772
#
#        L3_NO2_NO2_slant_column_number_density  L3_NO2_absorbing_aerosol_index  \
# count                            16383.000000                    16383.000000
# mean                                 0.000191                       -1.277031
# std                                  0.000109                        0.483440
# min                                  0.000061                       -3.115555
# 25%                                  0.000136                       -1.589061
# 50%                                  0.000165                       -1.297460
# 75%                                  0.000207                       -0.989069
# max                                  0.002431                        3.436194
#
#        L3_NO2_cloud_fraction  L3_NO2_sensor_altitude  \
# count           1.638300e+04            16383.000000
# mean            1.715506e-01           832342.865844
# std             1.798503e-01             3176.725391
# min             1.828210e-08           828755.229333
# 25%             3.462711e-02           829929.168589
# 50%             1.027849e-01           831578.009105
# 75%             2.577064e-01           833716.915275
# max             1.000000e+00           844493.897695
#
#        L3_NO2_sensor_azimuth_angle  L3_NO2_sensor_zenith_angle  \
# count                 16383.000000                16383.000000
# mean                    -15.754368                   36.762183
# std                      73.141202                   18.434215
# min                    -111.466479                    0.427703
# 25%                     -97.829562                   21.481927
# 50%                     -15.006531                   40.172762
# 75%                      69.321448                   52.742941
# max                      77.709979                   65.977559
#
#        L3_NO2_solar_azimuth_angle  L3_NO2_solar_zenith_angle  \
# count                16383.000000               16383.000000
# mean                  -122.055820                  47.020717
# std                     65.191804                  13.297507
# min                   -179.609374                   8.703999
# 25%                   -164.926856                  37.131486
# 50%                   -155.707698                  47.502945
# 75%                    -82.750440                  57.011924
# max                    179.689052                  79.766466
#
#        L3_NO2_stratospheric_NO2_column_number_density  \
# count                                    16383.000000
# mean                                         0.000037
# std                                          0.000009
# min                                          0.000010
# 25%                                          0.000030
# 50%                                          0.000036
# 75%                                          0.000042
# max                                          0.000069
#
#        L3_NO2_tropopause_pressure  \
# count                16383.000000
# mean                 14075.017140
# std                   6009.282071
# min                   6156.074219
# 25%                   7311.869141
# 50%                  14425.989994
# 75%                  19230.824243
# max                  31571.790309
#
#        L3_NO2_tropospheric_NO2_column_number_density  \
# count                                   16383.000000
# mean                                        0.000062
# std                                         0.000076
# min                                        -0.000036
# 25%                                         0.000022
# 50%                                         0.000040
# 75%                                         0.000075
# max                                         0.001724
#
#        L3_O3_O3_column_number_density  L3_O3_O3_effective_temperature  \
# count                    16383.000000                    16383.000000
# mean                         0.140228                      227.802486
# std                          0.023242                        3.895752
# min                          0.100510                      201.932510
# 25%                          0.119615                      225.926348
# 50%                          0.137701                      228.154699
# 75%                          0.156463                      230.548062
# max                          0.237652                      238.094783
#
#        L3_O3_cloud_fraction  L3_O3_sensor_azimuth_angle  \
# count          1.638300e+04                16383.000000
# mean           2.449535e-01                  -15.898553
# std            2.099128e-01                   72.853977
# min            5.919053e-10                 -111.903004
# 25%            8.218412e-02                  -97.830356
# 50%            1.799262e-01                  -15.055935
# 75%            3.631511e-01                   69.313333
# max            9.951779e-01                   77.709979
#
#        L3_O3_sensor_zenith_angle  L3_O3_solar_azimuth_angle  \
# count               16383.000000               16383.000000
# mean                   36.831256                -121.655399
# std                    18.424322                  64.922909
# min                     0.443455                -178.824525
# 25%                    21.571544                -164.844836
# 50%                    40.383965                -155.639897
# 75%                    52.769355                 -79.548878
# max                    65.826033                 179.038234
#
#        L3_O3_solar_zenith_angle  L3_CO_CO_column_number_density  \
# count              16383.000000                    16383.000000
# mean                  47.037538                        0.036728
# std                   13.291124                        0.010084
# min                    8.703999                        0.013582
# 25%                   37.168432                        0.031137
# 50%                   47.501265                        0.035792
# 75%                   57.008073                        0.040464
# max                   79.548331                        0.148626
#
#        L3_CO_H2O_column_number_density  L3_CO_cloud_height  \
# count                     16383.000000        16383.000000
# mean                       1022.002877         1186.227682
# std                         925.743382         1246.778404
# min                          50.370261         -489.869019
# 25%                         441.694060          162.655018
# 50%                         745.708174          722.384356
# 75%                        1298.088403         1915.427012
# max                       19656.359702         4998.954102
#
#        L3_CO_sensor_altitude  L3_CO_sensor_azimuth_angle  \
# count           16383.000000                16383.000000
# mean           832345.365770                  -17.386610
# std              3158.780165                   73.191343
# min            828757.614878                 -105.369218
# 25%            829944.558424                  -95.105951
# 50%            831594.872011                  -17.259365
# 75%            833716.589540                   66.288106
# max            844553.121177                   78.137217
#
#        L3_CO_sensor_zenith_angle  L3_CO_solar_azimuth_angle  \
# count               16383.000000               16383.000000
# mean                   36.289367                -126.775210
# std                    18.260494                  66.780229
# min                     1.106947                -179.863876
# 25%                    21.159149                -165.633447
# 50%                    39.014066                -156.279477
# 75%                    52.136441                -124.764695
# max                    65.401539                 179.800989
#
#        L3_CO_solar_zenith_angle  L3_HCHO_HCHO_slant_column_number_density  \
# count              16383.000000                              16383.000000
# mean                  47.055273                                  0.000048
# std                   13.286953                                  0.000073
# min                    8.834107                                 -0.000518
# 25%                   37.182343                                  0.000002
# 50%                   47.543955                                  0.000040
# 75%                   57.002790                                  0.000087
# max                   79.764657                                  0.000553
#
#        L3_HCHO_cloud_fraction  L3_HCHO_sensor_azimuth_angle  \
# count            1.638300e+04                  16383.000000
# mean             1.810454e-01                    -17.560234
# std              1.224590e-01                     75.347824
# min              5.919053e-10                   -111.903004
# 25%              7.964563e-02                    -98.055323
# 50%              1.636010e-01                    -15.792894
# 75%              2.732617e-01                     69.363384
# max              6.157534e-01                     79.497434
#
#        L3_HCHO_sensor_zenith_angle  L3_HCHO_solar_azimuth_angle  \
# count                 16383.000000                 16383.000000
# mean                     36.544646                  -124.854199
# std                      18.516282                    67.100534
# min                       0.131470                  -179.790201
# 25%                      21.178821                  -165.012231
# 50%                      39.324671                  -156.099816
# 75%                      52.847639                  -117.675416
# max                      66.013434                   179.799479
#
#        L3_HCHO_solar_zenith_angle  \
# count                16383.000000
# mean                    47.058173
# std                     13.317475
# min                      8.703807
# 25%                     37.158487
# 50%                     47.550013
# 75%                     57.085569
# max                     79.606145
#
#        L3_HCHO_tropospheric_HCHO_column_number_density  \
# count                                     16383.000000
# mean                                          0.000093
# std                                           0.000088
# min                                          -0.000630
# 25%                                           0.000034
# 50%                                           0.000079
# 75%                                           0.000138
# max                                           0.000609
#
#        L3_HCHO_tropospheric_HCHO_column_number_density_amf  \
# count                                       16383.000000
# mean                                            1.090963
# std                                             0.319700
# min                                             0.367346
# 25%                                             0.878908
# 50%                                             1.033028
# 75%                                             1.242995
# max                                             3.099836
#
#        L3_CLOUD_cloud_base_height  L3_CLOUD_cloud_base_pressure  \
# count                16383.000000                  16383.000000
# mean                  2013.048747                  81734.687990
# std                   1840.850229                  15571.871530
# min                      8.997803                  14547.019531
# 25%                    642.087415                  72998.817466
# 50%                   1501.636884                  85105.152384
# 75%                   2802.472645                  94284.243245
# max                  13801.821103                 101299.000000
#
#        L3_CLOUD_cloud_fraction  L3_CLOUD_cloud_optical_depth  \
# count             1.638300e+04                  16383.000000
# mean              2.463562e-01                      8.612266
# std               2.123012e-01                      8.516577
# min               6.152374e-10                      1.000000
# 25%               8.179518e-02                      4.795894
# 50%               1.801930e-01                      5.647700
# 75%               3.671341e-01                      8.955600
# max               9.959921e-01                    165.416324
#
#        L3_CLOUD_cloud_top_height  L3_CLOUD_cloud_top_pressure  \
# count               16383.000000                 16383.000000
# mean                 2696.870592                 75627.667492
# std                  2027.041045                 16334.187704
# min                    10.049448                 12388.570312
# 25%                  1254.291701                 65581.048508
# 50%                  2194.361074                 78335.325713
# 75%                  3669.492571                 87938.175776
# max                 14801.821103                101299.000000
#
#        L3_CLOUD_sensor_azimuth_angle  L3_CLOUD_sensor_zenith_angle  \
# count                   16383.000000                  16383.000000
# mean                      -15.874067                     36.851439
# std                        72.880304                     18.439937
# min                      -111.903004                      0.443455
# 25%                       -97.830192                     21.557220
# 50%                       -15.006784                     40.407892
# 75%                        69.318181                     52.811061
# max                        77.709979                     65.953701
#
#        L3_CLOUD_solar_azimuth_angle  L3_CLOUD_solar_zenith_angle  \
# count                  16383.000000                 16383.000000
# mean                    -121.543188                    47.037557
# std                       65.261951                    13.292992
# min                     -178.824525                     8.703999
# 25%                     -164.823068                    37.168432
# 50%                     -155.639897                    47.506474
# 75%                      -79.660545                    57.011338
# max                      179.038234                    79.548331
#
#        L3_CLOUD_surface_albedo  L3_AER_AI_absorbing_aerosol_index  \
# count             16383.000000                       16383.000000
# mean                  0.216022                          -1.268465
# std                   0.091735                           0.485371
# min                   0.015649                          -3.114718
# 25%                   0.164961                          -1.585364
# 50%                   0.204152                          -1.289796
# 75%                   0.247722                          -0.974460
# max                   0.965596                           3.419767
#
#        L3_AER_AI_sensor_altitude  L3_AER_AI_sensor_azimuth_angle  \
# count               16383.000000                    16383.000000
# mean               832347.854512                      -15.282990
# std                  3178.211676                       72.395578
# min                828758.030458                     -107.581297
# 25%                829930.230883                      -97.751579
# 50%                831579.458541                      -14.990631
# 75%                833729.022621                       69.317001
# max                844493.897695                       77.709979
#
#        L3_AER_AI_sensor_zenith_angle  L3_AER_AI_solar_azimuth_angle  \
# count                   16383.000000                   16383.000000
# mean                       36.937020                    -120.835842
# std                        18.442589                      65.177649
# min                         0.427703                    -177.344189
# 25%                        21.631384                    -164.816461
# 50%                        40.549872                    -155.547800
# 75%                        52.852962                     -73.605478
# max                        66.057880                     177.488723
#
#        L3_AER_AI_solar_zenith_angle  L3_SO2_SO2_column_number_density  \
# count                  16383.000000                      16383.000000
# mean                      47.014906                          0.000114
# std                       13.303190                          0.000820
# min                        8.703999                         -0.038756
# 25%                       37.127075                         -0.000097
# 50%                       47.466946                          0.000062
# 75%                       57.010291                          0.000270
# max                       81.334912                          0.014742
#
#        L3_SO2_SO2_column_number_density_amf  \
# count                          16383.000000
# mean                               0.444242
# std                                0.234443
# min                                0.100520
# 25%                                0.273333
# 50%                                0.396702
# 75%                                0.561093
# max                                2.184119
#
#        L3_SO2_SO2_slant_column_number_density  L3_SO2_absorbing_aerosol_index  \
# count                            16383.000000                    16383.000000
# mean                                 0.000034                       -1.953182
# std                                  0.000158                        0.625611
# min                                 -0.004309                       -4.582682
# 25%                                 -0.000040                       -2.339970
# 50%                                  0.000026                       -1.949433
# 75%                                  0.000095                       -1.578678
# max                                  0.006988                        3.589456
#
#        L3_SO2_cloud_fraction  L3_SO2_sensor_azimuth_angle  \
# count           1.638300e+04                 16383.000000
# mean            1.894281e-01                   -17.276292
# std             1.325387e-01                    75.702517
# min             5.919053e-10                  -111.997123
# 25%             7.985091e-02                   -98.124142
# 50%             1.662327e-01                   -15.646155
# 75%             2.884146e-01                    69.347821
# max             6.157045e-01                    78.902242
#
#        L3_SO2_sensor_zenith_angle  L3_SO2_solar_azimuth_angle  \
# count                16383.000000                16383.000000
# mean                    36.388198                 -125.139513
# std                     18.462287                   67.941354
# min                      0.131470                 -179.615693
# 25%                     21.119977                 -165.146119
# 50%                     38.922142                 -156.289068
# 75%                     52.602804                 -120.320080
# max                     65.967400                  179.747060
#
#        L3_SO2_solar_zenith_angle
# count               16383.000000
# mean                   47.045646
# std                    13.292591
# min                     8.703999
# 25%                    37.165640
# 50%                    47.547937
# 75%                    57.080116
# max                    79.606145
