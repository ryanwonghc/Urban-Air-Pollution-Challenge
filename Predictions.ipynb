# %%
from pycaret.regression import *
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Test_Processed.csv')
df
# Out:
#             Place_ID X Date        Date Place_ID  month  day  Place_ID_Group  \
# 0      0OS9LVX X 2020-01-02  2020-01-02  0OS9LVX      1    2               0
# 1      0OS9LVX X 2020-01-03  2020-01-03  0OS9LVX      1    3               0
# 2      0OS9LVX X 2020-01-04  2020-01-04  0OS9LVX      1    4               0
# 3      0OS9LVX X 2020-01-05  2020-01-05  0OS9LVX      1    5               0
# 4      0OS9LVX X 2020-01-06  2020-01-06  0OS9LVX      1    6               0
# ...                     ...         ...      ...    ...  ...             ...
# 16131  ZZDJZMS X 2020-03-31  2020-03-31  ZZDJZMS      3   31              35
# 16132  ZZDJZMS X 2020-04-01  2020-04-01  ZZDJZMS      4    1              35
# 16133  ZZDJZMS X 2020-04-02  2020-04-02  ZZDJZMS      4    2              35
# 16134  ZZDJZMS X 2020-04-03  2020-04-03  ZZDJZMS      4    3              35
# 16135  ZZDJZMS X 2020-04-04  2020-04-04  ZZDJZMS      4    4              35
#
# ...

# %%
model = load_model('Final Catboost Model')
# Out:
# Transformation Pipeline and Model Sucessfully Loaded

# %%
unseen_predictions = predict_model(model, data=df)
unseen_predictions.head()
# Out:
#         Place_ID X Date        Date Place_ID  month  day  Place_ID_Group  \
# 0  0OS9LVX X 2020-01-02  2020-01-02  0OS9LVX      1    2               0
# 1  0OS9LVX X 2020-01-03  2020-01-03  0OS9LVX      1    3               0
# 2  0OS9LVX X 2020-01-04  2020-01-04  0OS9LVX      1    4               0
# 3  0OS9LVX X 2020-01-05  2020-01-05  0OS9LVX      1    5               0
# 4  0OS9LVX X 2020-01-06  2020-01-06  0OS9LVX      1    6               0
#
#    precipitable_water_entire_atmosphere  relative_humidity_2m_above_ground  \
# 0                             11.600000                          30.200001
# 1                             18.300001                          42.900002
# 2                             17.600000                          41.299999
# 3                             15.011948                          53.100002
# 4                              9.700000                          71.599998
#
#    specific_humidity_2m_above_ground  temperature_2m_above_ground  \
# ...

# %%
submit = pd.read_csv('SampleSubmission.csv')
submit
# Out:
#             Place_ID X Date  target
# 0      0OS9LVX X 2020-01-02       0
# 1      0OS9LVX X 2020-01-03       0
# 2      0OS9LVX X 2020-01-04       0
# 3      0OS9LVX X 2020-01-05       0
# 4      0OS9LVX X 2020-01-06       0
# ...                     ...     ...
# 16131  ZZDJZMS X 2020-03-31       0
# 16132  ZZDJZMS X 2020-04-01       0
# 16133  ZZDJZMS X 2020-04-02       0
# 16134  ZZDJZMS X 2020-04-03       0
# 16135  ZZDJZMS X 2020-04-04       0
#
# [16136 rows x 2 columns]

# %%
# Get prediction
target = unseen_predictions.Label
submit.target = target

# %%
submit
# Out:
#             Place_ID X Date   target
# 0      0OS9LVX X 2020-01-02  64.4401
# 1      0OS9LVX X 2020-01-03  59.1835
# 2      0OS9LVX X 2020-01-04  80.9208
# 3      0OS9LVX X 2020-01-05  64.4044
# 4      0OS9LVX X 2020-01-06  64.4044
# ...                     ...      ...
# 16131  ZZDJZMS X 2020-03-31  48.7216
# 16132  ZZDJZMS X 2020-04-01  47.1770
# 16133  ZZDJZMS X 2020-04-02  48.2238
# 16134  ZZDJZMS X 2020-04-03  61.0794
# 16135  ZZDJZMS X 2020-04-04  52.0675
#
# [16136 rows x 2 columns]

# %%
submit.to_csv('submission_v2.csv', index=False)
